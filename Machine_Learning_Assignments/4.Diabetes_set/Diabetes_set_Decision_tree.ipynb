# %% [markdown]
# ## import pandas library

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\12 Th Science\ML_Practice_Day_Series\diabetes_dataset.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#feature variables
x=df.drop(['Outcome'], axis=1)
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
#target variable
y=df.Outcome
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
# Create Decision Tree classifer object
model = DecisionTreeClassifier()

# Train Decision Tree Classifer
model = model.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = model.predict(x_test)

# %%
#Evaluation using Accuracy score
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 70.12987012987013

# %%
#Evaluation using Confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[79, 20],
#        [26, 29]], dtype=int64)

# %%
print("Accuracy:",((82+27)/154))
# Out:
# Accuracy: 0.7077922077922078

# %%
#Evaluation using Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        99
#            1       0.59      0.53      0.56        55
#
#     accuracy                           0.70       154
#    macro avg       0.67      0.66      0.67       154
# weighted avg       0.70      0.70      0.70       154

# %%
#checking prediction value
model.predict([[6,148,72,35,0,33.6,0.627,50]])
# Out:
# c:\Users\Gopal Chavan\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
pip install pydotplus
# Out:
# Collecting pydotplusNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ---------------------------------------- 0.0/278.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/278.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/278.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/278.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/278.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/278.7 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/278.7 kB 109.5 kB/s eta 0:00:03
#      ---- -------------------------------- 30.7/278.7 kB 109.5 kB/s eta 0:00:03
#      ---- -------------------------------- 30.7/278.7 kB 109.5 kB/s eta 0:00:03
#      ---- -------------------------------- 30.7/278.7 kB 109.5 kB/s eta 0:00:03
#      ---- -------------------------------- 30.7/278.7 kB 109.5 kB/s eta 0:00:03
#      ----- -------------------------------- 41.0/278.7 kB 73.0 kB/s eta 0:00:04
#      ----- -------------------------------- 41.0/278.7 kB 73.0 kB/s eta 0:00:04
#      ---------- -------------------------- 81.9/278.7 kB 139.2 kB/s eta 0:00:02
#      ---------- -------------------------- 81.9/278.7 kB 139.2 kB/s eta 0:00:02
#      ------------ ------------------------ 92.2/278.7 kB 141.7 kB/s eta 0:00:02
#      -------------- --------------------- 112.6/278.7 kB 163.8 kB/s eta 0:00:02
#      --------------- -------------------- 122.9/278.7 kB 164.0 kB/s eta 0:00:01
#      --------------- -------------------- 122.9/278.7 kB 164.0 kB/s eta 0:00:01
#      --------------- -------------------- 122.9/278.7 kB 164.0 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/278.7 kB 163.9 kB/s eta 0:00:01
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      --------------------- --------------- 163.8/278.7 kB 69.7 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ----------------------- ------------- 174.1/278.7 kB 63.6 kB/s eta 0:00:02
#      ------------------------- ----------- 194.6/278.7 kB 55.4 kB/s eta 0:00:02
#      ------------------------- ----------- 194.6/278.7 kB 55.4 kB/s eta 0:00:02
#      --------------------------- --------- 204.8/278.7 kB 56.6 kB/s eta 0:00:02
#      --------------------------- --------- 204.8/278.7 kB 56.6 kB/s eta 0:00:02
#      --------------------------- --------- 204.8/278.7 kB 56.6 kB/s eta 0:00:02
#      --------------------------- --------- 204.8/278.7 kB 56.6 kB/s eta 0:00:02
#      --------------------------- --------- 204.8/278.7 kB 56.6 kB/s eta 0:00:02
#      ----------------------------- ------- 225.3/278.7 kB 58.8 kB/s eta 0:00:01
#      ----------------------------- ------- 225.3/278.7 kB 58.8 kB/s eta 0:00:01
#      ----------------------------- ------- 225.3/278.7 kB 58.8 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      -------------------------------- ---- 245.8/278.7 kB 62.3 kB/s eta 0:00:01
#      --------------------------------- --- 256.0/278.7 kB 57.6 kB/s eta 0:00:01
#      --------------------------------- --- 256.0/278.7 kB 57.6 kB/s eta 0:00:01
#      --------------------------------- --- 256.0/278.7 kB 57.6 kB/s eta 0:00:01
#      --------------------------------- --- 256.0/278.7 kB 57.6 kB/s eta 0:00:01
#      ------------------------------------- 278.7/278.7 kB 60.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\gopal chavan\anaconda3\lib\site-packages (from pydotplus) (3.0.9)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py): started
#   Building wheel for pydotplus (setup.py): finished with status 'done'
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24578 sha256=66c6bdcdce977966723ef3eb65cdb1e9aac3c081d6137db2d2d00d8f01128d65
#   Stored in directory: c:\users\gopal chavan\appdata\local\pip\cache\wheels\bd\ce\e8\ff9d9c699514922f57caa22fbd55b0a32761114b4c4acc9e03
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2

# %%
from io import StringIO
from sklearn.tree import export_graphviz
from io import StringIO
from IPython.display import Image
import pydotplus

# %%
#Import modules for Visualizing Decision trees
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 3
#       1 #Import modules for Visualizing Decision trees
#       2 from sklearn.tree import export_graphviz
# ----> 3 from sklearn.externals.six import StringIO
#       4 from IPython.display import Image
#       5 import pydotplus
#
# ModuleNotFoundError: No module named 'sklearn.externals.six'

# %%
features=x.columns
features
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,filled=True, rounded=True,special_characters=True,feature_names = features,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes_set.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[31], line 4
#       2 export_graphviz(model, out_file=dot_data,filled=True, rounded=True,special_characters=True,feature_names = features,class_names=['0','1'])
#       3 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ----> 4 graph.write_png('diabetes_set.png')
#       5 Image(graph.create_png())
#
# File c:\Users\Gopal Chavan\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File c:\Users\Gopal Chavan\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File c:\Users\Gopal Chavan\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

# %%
# Create Decision Tree classifer object
model = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
model = model.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = model.predict(x_test)

# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 79.87012987012987

# %%
#Better Decision Tree Visualisation
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,filled=True, rounded=True,special_characters=True, feature_names = features,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes_set.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 #Better Decision Tree Visualisation
# ----> 2 from sklearn.externals.six import StringIO
#       3 from IPython.display import Image
#       4 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'sklearn.externals.six'
